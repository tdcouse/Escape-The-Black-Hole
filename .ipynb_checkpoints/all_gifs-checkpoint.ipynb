# %% [markdown]
# ### These are all the function we will need imported from our own module

# %%
import numpy as np
import matplotlib.pyplot as py
from scipy.integrate import odeint
import matplotlib.animation as animation
import matplotlib.colors as mcolors
from module import deriv
from module import diffeq_solver_from_scipy
from IPython.display import Image

# %% [markdown]
# # Do Nothing and Get Sucked In

# %%
#Escape the Black Hole game  --  SMALL SCALE
G = 6.67430*(10**(-11))
mBH = 5.1714*(10**36)#Mass Sagitatius A
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V


#Schwarzschild radius of Sagitarius A is 7.86e9 m

xS0 = 0.0
vxS0 = (.2*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 3.4*(10**(10))
#vyS0 = (0.96)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (-0.5)*(3*(10**8)) #m/s up to this speed will never escape the black hole
#vyS0 = (0.988)*(3*(10**8)) #m/s minimum speed to escape, there is not speed possible above 1.0*c - for most calculating plot above, not this particlar small scale view
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -10.7*(10**(10))
vxA0 = (0.01)*(3*(10**8))
yA0 = 0.0
vyA0 =  np.sqrt(G*mBH/np.abs(xA0))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0]
tmin = 0
tmax = 151
nts = 200

params = (G, mBH, mA, mS)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]

circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
#circle1 = py.Circle((0, 0), 90.8*(10**(10)), color='k') #Event horizon is plotted as 53 times the actual size for better perspective
img = py.imread("crazy2.jpg")

py.plot(xS, yS, 'r4',label='Ship Orbit')
py.plot(xA, yA, 'm.', label='Unidentified Flying Object')
py.plot(xBH, yBH,'kX',label='Black Hole')
py.legend(loc='lower right')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")

#py.xlim(-20.5*(10**10), 20.5*(10**10))
#py.ylim(-10.5*(10**10), 40.5*(10**10))

py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
py.ylim(-14.5*(10**(10)), 15.5*(10**(10)))

ax.add_artist(circle1)
ax.imshow(img,extent=[-27.5*(10**(10)), 31.5*(10**(10)), -29.5*(10**(10)), 25.5*(10**(10))])
py.rcParams["figure.figsize"] = (12, 12)
py.show()

# %%
import matplotlib.animation as animation
import matplotlib.colors as mcolors
img =  py.imread("crazy2.jpg")
fig = py.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-15.5*(10**(10)), 15.5*(10**(10)))
ax.set_ylim(-14.5*(10**(10)), 15.5*(10**(10)))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xA[:i], yA[:i], color='cadetblue')
    line1e, = ax.plot(xA[head_e], yA[head_e], color='slategrey',marker='o', markersize = 40)
    line2, = ax.plot(xS[:i], yS[:i], color='orangered')
    line2e, = ax.plot(xS[head_e], yS[head_e], color='darkcyan',marker='4', markersize = 26)
    lines.append([line1,line1e,line2,line2e])
ax.add_artist(circle1)
ax.imshow(img,extent=[-27.5*(10**(10)), 31.5*(10**(10)), -29.5*(10**(10)), 25.5*(10**(10))])
py.legend([line1e, line2e, circle1], ['UFO','Ship','Black Hole'],loc='upper left',prop={'size': 18})
ani = animation.ArtistAnimation(fig,lines,interval=25,blit=True)
ani.save('do_nothing.gif')

# %%
with open('do_nothing.gif','rb') as file:
    display(Image(file.read())) #fall in

# %%
G = 6.67430*(10**(-11))
mBH = 5.1714*(10**36)#Mass Sagitatius A
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V


#Schwarzschild radius of Sagitarius A is 7.86e9 m

xS0 = 0.0
vxS0 = (0.21*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 0.786*(10**(10))
#vyS0 = (0.96)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (0.962)*(3*(10**8)) #m/s up to this speed will never escape the black hole
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -10.7*(10**(10))
vxA0 = (0.01)*(3*(10**8))
yA0 = 0.0
vyA0 =  np.sqrt(G*mBH/np.abs(xA0))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0]
tmin = 0
tmax = 160500
nts = 400

params = (G, mBH, mA, mS)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]

circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
#circle1 = py.Circle((0, 0), 90.8*(10**(10)), color='k') #Event horizon is plotted as 53 times the actual size for better perspective
img = py.imread("crazy2.jpg")

py.plot(xS, yS, 'r4',label='Ship Orbit')
py.plot(xA, yA, 'm.', label='Unidentified Flying Object')
py.plot(xBH, yBH,'kX',label='Black Hole')
py.legend(loc='lower right')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")

py.xlim(-2.5*(10**11), 5.5*(10**11))
py.ylim(-2*(10**11), 1.2*(10**12))

#py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
#py.ylim(-20.5*(10**(10)), 25.5*(10**(10)))

ax.add_artist(circle1)
ax.imshow(img,extent=[-13.75*(10**(11)), 15.75*(10**(11)), -15.1*(10**(11)), 12.75*(10**(11))])
py.rcParams["figure.figsize"] = (12, 12)
py.show()

# %% [markdown]
# # V = .985c

# %%
img =  py.imread("crazy2.jpg")
fig = py.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-2.5*(10**11), 5.5*(10**11))
ax.set_ylim(-2*(10**11), 1.2*(10**12))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xA[:i], yA[:i], color='cadetblue')
    line1e, = ax.plot(xA[head_e], yA[head_e], color='slategrey',marker='o', markersize = 30)
    line2, = ax.plot(xS[:i], yS[:i], color='orangered')
    line2e, = ax.plot(xS[head_e], yS[head_e], color='darkcyan',marker='4', markersize = 26)
    lines.append([line1,line1e,line2,line2e])
ax.add_artist(circle1)
ax.imshow(img,extent=[-13.75*(10**(11)), 15.75*(10**(11)), -15.1*(10**(11)), 12.75*(10**(11))])
py.legend([line1e, line2e, circle1], ['UFO','Ship','Black Hole'],loc='upper left',prop={'size': 18})
ani = animation.ArtistAnimation(fig,lines,interval=25,blit=True)
ani.save('black_hole_985.gif')

# %%
with open('black_hole_985.gif','rb') as file:
    display(Image(file.read())) #fall in

# %%
G = 6.67430*(10**(-11))
mBH = 5.1714*(10**36)#Mass Sagitatius A
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V


#Schwarzschild radius of Sagitarius A is 7.86e9 m

xS0 = 0.0
vxS0 = (0.21*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 0.786*(10**(10))
#vyS0 = (0.96)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (0.97)*(3*(10**8)) #m/s up to this speed will never escape the black hole
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -10.7*(10**(10))
vxA0 = (0.01)*(3*(10**8))
yA0 = 0.0
vyA0 =  np.sqrt(G*mBH/np.abs(xA0))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0]
tmin = 0
tmax = 28000
nts = 500

params = (G, mBH, mA, mS)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]

circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
#circle1 = py.Circle((0, 0), 90.8*(10**(10)), color='k') #Event horizon is plotted as 53 times the actual size for better perspective
img = py.imread("crazy2.jpg")

py.plot(xS, yS, 'r4',label='Ship Orbit')
py.plot(xA, yA, 'm.', label='Unidentified Flying Object')
py.plot(xBH, yBH,'kX',label='Black Hole')
py.legend(loc='lower right')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")

py.xlim(-2.5*(10**11), 5.5*(10**11))
py.ylim(-2*(10**11), 1.2*(10**12))

#py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
#py.ylim(-20.5*(10**(10)), 25.5*(10**(10)))

ax.add_artist(circle1)
ax.imshow(img,extent=[-13.75*(10**(11)), 15.75*(10**(11)), -15.1*(10**(11)), 12.75*(10**(11))])
py.rcParams["figure.figsize"] = (12, 12)
py.show()

# %% [markdown]
# # 0.992c Escape

# %%
img =  py.imread("crazy2.jpg")
fig = py.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-2.5*(10**11), 5.5*(10**11))
ax.set_ylim(-2*(10**11), 1.2*(10**12))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xA[:i], yA[:i], color='cadetblue')
    line1e, = ax.plot(xA[head_e], yA[head_e], color='slategrey',marker='o', markersize = 30)
    line2, = ax.plot(xS[:i], yS[:i], color='orangered')
    line2e, = ax.plot(xS[head_e], yS[head_e], color='darkcyan',marker='4', markersize = 26)
    lines.append([line1,line1e,line2,line2e])
ax.add_artist(circle1)
ax.imshow(img,extent=[-13.75*(10**(11)), 15.75*(10**(11)), -15.1*(10**(11)), 12.75*(10**(11))])
py.legend([line1e, line2e, circle1], ['UFO','Ship','Black Hole'],loc='upper left',prop={'size': 18})
ani = animation.ArtistAnimation(fig,lines,interval=25,blit=True)
ani.save('black_hole_992.gif')

# %%
with open('black_hole_992.gif','rb') as file:
    display(Image(file.read())) #fall in

# %%
G = 6.67430*(10**(-11))
mBH = 5.1714*(10**36)#Mass Sagitatius A
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V


#Schwarzschild radius of Sagitarius A is 7.86e9 m

xS0 = 0.0
vxS0 = (0.21*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 0.786*(10**(10))
#vyS0 = (0.96)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (0.9508)*(3*(10**8)) #m/s up to this speed will never escape the black hole
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -10.7*(10**(10))
vxA0 = (0.01)*(3*(10**8))
yA0 = 0.0
vyA0 =  np.sqrt(G*mBH/np.abs(xA0))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0]
tmin = 0
tmax = 17360
nts = 1000

params = (G, mBH, mA, mS)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]

circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
#circle1 = py.Circle((0, 0), 90.8*(10**(10)), color='k') #Event horizon is plotted as 53 times the actual size for better perspective
img = py.imread("crazy2.jpg")

py.plot(xS, yS, 'r4',label='Ship Orbit')
py.plot(xA, yA, 'm.', label='Unidentified Flying Object')
py.plot(xBH, yBH,'kX',label='Black Hole')
py.legend(loc='lower right')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")

py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
py.ylim(-20.5*(10**(10)), 25.5*(10**(10)))

#py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
#py.ylim(-20.5*(10**(10)), 25.5*(10**(10)))

ax.add_artist(circle1)
ax.imshow(img,extent=[-27.5*(10**(10)), 31.5*(10**(10)), -29.5*(10**(10)), 25.5*(10**(10))])
py.rcParams["figure.figsize"] = (12, 12)
py.show()

# %% [markdown]
# # 0.973 Escape

# %%
img =  py.imread("crazy2.jpg")
fig = py.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-15.5*(10**(10)), 15.5*(10**(10)))
ax.set_ylim(-20.5*(10**(10)), 25.5*(10**(10)))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xA[:i], yA[:i], color='cadetblue')
    line1e, = ax.plot(xA[head_e], yA[head_e], color='slategrey',marker='o', markersize = 30)
    line2, = ax.plot(xS[:i], yS[:i], color='orangered')
    line2e, = ax.plot(xS[head_e], yS[head_e], color='darkcyan',marker='4', markersize = 26)
    lines.append([line1,line1e,line2,line2e])
ax.add_artist(circle1)
ax.imshow(img,extent=[-27.5*(10**(10)), 31.5*(10**(10)), -29.5*(10**(10)), 25.5*(10**(10))])
py.legend([line1e, line2e, circle1], ['UFO','Ship','Black Hole'],loc='upper left',prop={'size': 18})
ani = animation.ArtistAnimation(fig,lines,interval=25,blit=True)
ani.save('black_hole_973.gif')

# %%
with open('black_hole_973.gif','rb') as file:
    display(Image(file.read()))

# %% [markdown]
# # Captured by Aliens

# %%
#Escape the Black Hole game -- Aliens catch you
import numpy as np
import matplotlib.pyplot as py
from scipy.integrate import odeint


def deriv(s, t, G, mBH, mA, mS, mSD):
  xS0 = s[0]
  vxS0 = s[1]
  yS0 = s[2]
  vyS0 = s[3]
  xBH0 = s[4]
  vxBH0 = s[5]
  yBH0 = s[6]
  vyBH0 = s[7]
  xA0 = s[8]
  vxA0 = s[9]
  yA0 = s[10]
  vyA0 = s[11]
  xSD0 = s[12]
  vxSD0 = s[13]
  ySD0 = s[14]
  vySD0 = s[15]

  f1 = vxS0
  f2 = ((G*mA*(xA0-xS0))/(((xA0-xS0)**2+(yA0-yS0)**2)**(1.5))) + ((G*mBH*(xBH0-xS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
  f3 = vyS0
  f4 = ((G*mA*(yA0-yS0))/(((xA0-xS0)**2+(yA0-yS0)**2)**(1.5))) + ((G*mBH*(yBH0-yS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
  f5 = vxBH0
  f6 = ((G*mA*(xA0-xBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mS*(xS0-xBH0))/(((xS0-xBH0)**2+(yS0-yBH0)**2)**(1.5)))
  f7 = vyBH0
  f8 = ((G*mA*(yA0-yBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mS*(yS0-yBH0))/(((xS0-xBH0)**2+(yS0-yBH0)**2)**(1.5)))
  f9 = vxA0
  f10 = ((G*mS*(xS0-xA0))/(((xS0-xA0)**2+(yS0-yA0)**2)**(1.5))) + ((G*mBH*(xBH0-xA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
  f11 = vyA0
  f12 = ((G*mS*(yS0-yA0))/(((xS0-xA0)**2+(yS0-yA0)**2)**(1.5))) + ((G*mBH*(yBH0-yA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
  f13 = vxSD0
  f14 = ((G*mSD*(xA0-xSD0))/(((xA0-xSD0)**2+(yA0-ySD0)**2)**(1.5))) + ((G*mBH*(xBH0-xSD0))/(((xBH0-xSD0)**2+(yBH0-ySD0)**2)**(1.5)))
  f15 = vySD0
  f16 = ((G*mSD*(yA0-ySD0))/(((xA0-xSD0)**2+(yA0-ySD0)**2)**(1.5))) + ((G*mBH*(yBH0-ySD0))/(((xBH0-xSD0)**2+(yBH0-ySD0)**2)**(1.5)))
  
  #We are saying the alien ship is no longer a death star, but instead a star destroyer, a second large alien space ship
  
  
  return [f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f16]

def diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params):
    t = np.linspace(tmin,tmax,nts)
    s = odeint(deriv, s_initial, t, params)
    
    return t,s

G = 6.67430*(10**(-11))
mBH = 5.1714*(10**36)#Mass Sagitatius A
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V
mSD = mA = 100.0*(10**6)#Mass of star destroyer

#Schwarzschild radius of Sagitarius A is 7.86e9 m

xS0 = 0.0
vxS0 = (0.21*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 0.786*(10**(10))
#vyS0 = (0.96)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (0.95)*(3*(10**8)) #m/s up to this speed will never escape the black hole
#vyS0 = (0.988)*(3*(10**8)) #m/s minimum speed to escape, there is not speed possible above 1.0*c - for most calculating plot above, not this particlar small scale view
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -8.7*(10**(10))
vxA0 = (0.01)*(3*(10**8))
yA0 = 0.0
vyA0 =  np.sqrt(G*mBH/np.abs(xA0))
xSD0 = 16.7*(10**(10))
vxSD0 = -(0.085)*(3*(10**8))
ySD0 = 2.7*(10**(10))
vySD0 =  -(0.117*(3*(10**8)))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0, xSD0, vxSD0, ySD0, vySD0]
tmin = 0
tmax = 10319
nts = 250

params = (G, mBH, mA, mS, mSD)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]
xSD = s[:,12]
vxSD = s[:,13]
ySD = s[:,14]
vySD = s[:,15]

circle1 = py.Circle((0, 0), 7.8*(10**(9)), color='k')
img = py.imread("crazy2.jpg")

py.plot(xS, yS, 'r3',label='Ship Orbit')
py.plot(xA, yA, 'm.', label='UFO')
py.plot(xBH, yBH,'kX',label='Singularity')
py.plot(xSD, ySD,'c4',label='Hostile Aliens')
py.legend(loc='lower right')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")
py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
py.ylim(-20.5*(10**(10)), 25.5*(10**(10)))
ax.add_artist(circle1)
ax.imshow(img,extent=[-27.5*(10**(10)), 31.5*(10**(10)), -29.5*(10**(10)), 25.5*(10**(10))])
py.rcParams["figure.figsize"] = (16, 15)
py.show()

# %%
import matplotlib.animation as animation
import matplotlib.colors as mcolors
img =  py.imread("crazy2.jpg")
fig = py.figure(figsize=(16,16))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-15.5*(10**(10)), 15.5*(10**(10)))
ax.set_ylim(-20.5*(10**(10)), 25.5*(10**(10)))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xA[:i], yA[:i], color='cadetblue')
    line1e, = ax.plot(xA[head_e], yA[head_e], color='slategrey',marker='o', markersize = 40)
    line2, = ax.plot(xS[:i], yS[:i], color='orangered')
    line2e, = ax.plot(xS[head_e], yS[head_e], color='darkcyan',marker='4', markersize = 23)
    line3, = ax.plot(xSD[:i], ySD[:i], color='darkorange')
    line3e, = ax.plot(xSD[head_e], ySD[head_e], color='darkred',marker='3', markersize = 33)
    lines.append([line1,line1e,line2,line2e,line3,line3e])
ax.add_artist(circle1)
ax.imshow(img,extent=[-27.5*(10**(10)), 31.5*(10**(10)), -29.5*(10**(10)), 25.5*(10**(10))])
py.legend([line1e, line2e, line3e, circle1], ['UFO','Ship','Hostile Aliens', 'Black Hole'],loc='upper left',prop={'size': 16})
ani = animation.ArtistAnimation(fig,lines,interval=20,blit=True)
ani.save('alien_intersect.gif')

# %%
with open('alien_intersect.gif','rb') as file:
    display(Image(file.read()))

# %% [markdown]
# # Alien Escape

# %%
#Escape the Black Hole game -- escape aliens
import numpy as np
import matplotlib.pyplot as py
from scipy.integrate import odeint


def deriv(s, t, G, mBH, mA, mS, mSD):
  xS0 = s[0]
  vxS0 = s[1]
  yS0 = s[2]
  vyS0 = s[3]
  xBH0 = s[4]
  vxBH0 = s[5]
  yBH0 = s[6]
  vyBH0 = s[7]
  xA0 = s[8]
  vxA0 = s[9]
  yA0 = s[10]
  vyA0 = s[11]
  xSD0 = s[12]
  vxSD0 = s[13]
  ySD0 = s[14]
  vySD0 = s[15]

  f1 = vxS0
  f2 = ((G*mA*(xA0-xS0))/(((xA0-xS0)**2+(yA0-yS0)**2)**(1.5))) + ((G*mBH*(xBH0-xS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
  f3 = vyS0
  f4 = ((G*mA*(yA0-yS0))/(((xA0-xS0)**2+(yA0-yS0)**2)**(1.5))) + ((G*mBH*(yBH0-yS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
  f5 = vxBH0
  f6 = ((G*mA*(xA0-xBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mS*(xS0-xBH0))/(((xS0-xBH0)**2+(yS0-yBH0)**2)**(1.5)))
  f7 = vyBH0
  f8 = ((G*mA*(yA0-yBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mS*(yS0-yBH0))/(((xS0-xBH0)**2+(yS0-yBH0)**2)**(1.5)))
  f9 = vxA0
  f10 = ((G*mS*(xS0-xA0))/(((xS0-xA0)**2+(yS0-yA0)**2)**(1.5))) + ((G*mBH*(xBH0-xA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
  f11 = vyA0
  f12 = ((G*mS*(yS0-yA0))/(((xS0-xA0)**2+(yS0-yA0)**2)**(1.5))) + ((G*mBH*(yBH0-yA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
  f13 = vxSD0
  f14 = ((G*mA*(xA0-xSD0))/(((xA0-xSD0)**2+(yA0-ySD0)**2)**(1.5))) + ((G*mBH*(xBH0-xSD0))/(((xBH0-xSD0)**2+(yBH0-ySD0)**2)**(1.5)))
  f15 = vySD0
  f16 = ((G*mA*(yA0-ySD0))/(((xA0-xSD0)**2+(yA0-ySD0)**2)**(1.5))) + ((G*mBH*(yBH0-ySD0))/(((xBH0-xSD0)**2+(yBH0-ySD0)**2)**(1.5)))
  
  
  
  
  return [f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f16]

def diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params):
    t = np.linspace(tmin,tmax,nts)
    s = odeint(deriv, s_initial, t, params)
    
    return t,s

G = 6.67430*(10**(-11))
mBH = 5.1714*(10**36)#Mass Sagitatius A
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V
mSD = 100.0*(10**6)#Mass of star destroyer

#Schwarzschild radius of Sagitarius A is 7.86e9 m

xS0 = 0.0
vxS0 = -(0.09*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 0.83*(10**(10))
#vyS0 = (0.96)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (0.951)*(3*(10**8)) #m/s up to this speed will never escape the black hole
#vyS0 = (0.988)*(3*(10**8)) #m/s minimum speed to escape, there is not speed possible above 1.0*c - for most calculating plot above, not this particlar small scale view
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -8.7*(10**(10))
vxA0 = (0.01)*(3*(10**8))
yA0 = 0.0
vyA0 =  np.sqrt(G*mBH/np.abs(xA0))
xSD0 = 16.7*(10**(10))
vxSD0 = -(0.177)*(3*(10**8))
ySD0 = 2.7*(10**(10))
vySD0 =  -(0.119*(3*(10**8)))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0, xSD0, vxSD0, ySD0, vySD0]
tmin = 0
tmax = 10319
nts = 150

params = (G, mBH, mA, mS, mSD)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]
xSD = s[:,12]
vxSD = s[:,13]
ySD = s[:,14]
vySD = s[:,15]

circle1 = py.Circle((0, 0), 7.8*(10**(9)), color='k')
img = py.imread("crazy2.jpg")

py.plot(xS, yS, 'r3',label='Ship Orbit')
py.plot(xA, yA, 'm.', label='UFO')
py.plot(xBH, yBH,'kX',label='Singularity')
py.plot(xSD, ySD,'c4',label='Hostile Aliens')
py.legend(loc='lower right')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")
py.xlim(-15.5*(10**(10)), 15.5*(10**(10)))
py.ylim(-10.5*(10**(10)), 45.5*(10**(10)))
ax.add_artist(circle1)
ax.imshow(img,extent=[-47.5*(10**(10)), 54.5*(10**(10)), -52.5*(10**(10)), 45.5*(10**(10))])
py.rcParams["figure.figsize"] = (14, 14)
py.show()

# %%
import matplotlib.animation as animation
import matplotlib.colors as mcolors
img =  py.imread("crazy2.jpg")
fig = py.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-15.5*(10**(10)), 15.5*(10**(10)))
ax.set_ylim(-10.5*(10**(10)), 45.5*(10**(10)))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xA[:i], yA[:i], color='cadetblue')
    line1e, = ax.plot(xA[head_e], yA[head_e], color='slategrey',marker='o',markersize = 40)
    line2, = ax.plot(xS[:i], yS[:i], color='orangered')
    line2e, = ax.plot(xS[head_e], yS[head_e], color='darkcyan',marker='4',markersize = 23)
    line3, = ax.plot(xSD[:i], ySD[:i], color='darkorange')
    line3e, = ax.plot(xSD[head_e], ySD[head_e], color='darkred',marker='3',markersize = 33)
    lines.append([line1,line1e,line2,line2e,line3,line3e])
ax.add_artist(circle1)
ax.imshow(img,extent=[-47.5*(10**(10)), 54.5*(10**(10)), -52.5*(10**(10)), 45.5*(10**(10))])
py.legend([line1e, line2e, line3e, circle1], ['UFO','Ship','Hostile Aliens', 'Black Hole'],loc='upper right',prop={'size': 16})
ani = animation.ArtistAnimation(fig,lines,interval=20,blit=True)
ani.save('alien_escape.gif')

# %%
with open('alien_escape.gif','rb') as file:
    display(Image(file.read()))

# %% [markdown]
# # Binary Black Hole Death

# %%
#Escape the Black Hole game  Aliens catch you
#Black hole binary system at the heart of a faraway galaxy, OJ 287

def deriv(s, t, G, mBH, mA, mS, mSBH):
  xS0 = s[0]
  vxS0 = s[1]
  yS0 = s[2]
  vyS0 = s[3]
  xBH0 = s[4]
  vxBH0 = s[5]
  yBH0 = s[6]
  vyBH0 = s[7]
  xA0 = s[8]
  vxA0 = s[9]
  yA0 = s[10]
  vyA0 = s[11]
  xSBH0 = s[12]
  vxSBH0 = s[13]
  ySBH0 = s[14]
  vySBH0 = s[15]

  f1 = vxS0
  f2 = ((G*mSBH*(xSBH0-xS0))/(((xSBH0-xS0)**2+(ySBH0-yS0)**2)**(1.5))) + ((G*mBH*(xBH0-xS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
  f3 = vyS0
  f4 = ((G*mSBH*(ySBH0-yS0))/(((xSBH0-xS0)**2+(ySBH0-yS0)**2)**(1.5))) + ((G*mBH*(yBH0-yS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
  f5 = 0.04*vxBH0
  f6 = ((G*mA*(xA0-xBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mSBH*(xSBH0-xBH0))/(((xSBH0-xBH0)**2+(ySBH0-yBH0)**2)**(1.5)))
  f7 = 0.04*vyBH0
  f8 = ((G*mA*(yA0-yBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mSBH*(ySBH0-yBH0))/(((xSBH0-xBH0)**2+(ySBH0-yBH0)**2)**(1.5)))
  f9 = vxA0
  f10 = ((G*mSBH*(xSBH0-xA0))/(((xSBH0-xA0)**2+(ySBH0-yA0)**2)**(1.5))) + ((G*mBH*(xBH0-xA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
  f11 = vyA0
  f12 = ((G*mSBH*(ySBH0-yA0))/(((xSBH0-xA0)**2+(ySBH0-yA0)**2)**(1.5))) + ((G*mBH*(yBH0-yA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
  f13 = vxSBH0
  f14 = 1.002*((G*mBH*(xBH0-xSBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(xA0-xSBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
  #f14 = 1.3008*((G*mBH*(xBH0-xSBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(xA0-xSBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
  f15 = vySBH0
  f16 = 1.0*((G*mBH*(yBH0-ySBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(yA0-ySBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
  #f16 = 1.2955*((G*mBH*(yBH0-ySBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(yA0-ySBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
  
  
  
  
  return [f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f16]

def diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params):
    t = np.linspace(tmin,tmax,nts)
    s = odeint(deriv, s_initial, t, params)
    
    return t,s

#https://www.scientificamerican.com/article/astronomers-measure-how-fast-a-supermassive-black-hole-is-spinning/#:~:text=OJ%20287%2C%20a%20binary%20supermassive,mere%20150%20million%20solar%20masses.

G = 6.67430*(10**(-11))
mBH = 3.6498*(10**40)#Massive black hole - 18.35 billion solar masses
mSBH = 2.9835e38 #Smaller black hole - 150 million solar masses
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V


#Schwarzschild radius of Sagitarius A is 5.415e+10, 362AU

xS0 = -3.8121e12
vxS0 = (0.69005*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 7.0e12
vyS0 = (0.80446)*(3*(10**8)) #m/s - choose this to escape
#vyS0 = -20000*np.sqrt(G*mA/np.abs(xS0-xA0))
#vyS0 = (0.991)*(3*(10**8)) #m/s up to this speed will never escape the black hole
#vyS0 = (0.988)*(3*(10**8)) #m/s minimum speed to escape, there is not speed possible above 1.0*c - for most calculating plot above, not this particlar small scale view
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -4.7*(10**(12))
vxA0 = (0.72)*(3*(10**8))
yA0 = 0.0
vyA0 =  0.7426*np.sqrt(G*mBH/np.abs(xA0))
#vyA0 =  0.97*np.sqrt(G*mBH/np.abs(xA0))
#vyA0 =  0.9*np.sqrt(G*mBH/np.abs(xA0))
xSBH0 = 1.813*(10**(12)) #10 lightweeks
vxSBH0 = -(1.2)*(3*(10**8))
ySBH0 = 0.1*(10**(10))
vySBH0 =  -(2.29*(3*(10**8)))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0, xSBH0, vxSBH0, ySBH0, vySBH0]
tmin = 0
#tmax = 265200
#tmax = 5000000
tmax = 2.7322e5 #12 years
tmax = 105580
nts = 650
params = (G, mBH, mA, mS, mSBH)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]
xSBH = s[:,12]
vxSBH = s[:,13]
ySBH = s[:,14]
vySBH = s[:,15]

circle1 = py.Circle((0,0), 5.41*(10**(10)), color='k')
img = py.imread("black.jpg")


py.plot(xA, yA, 'm.', label='UFO')
py.plot(xSBH, ySBH,'b.',label='Smaller BH')
py.plot(xS, yS, 'r3',label='Ship Orbit')
py.plot(xBH, yBH,'ko',label='Massive BH', markersize = 5)
py.legend(loc='lower left')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")
py.xlim(-7.5*(10**(12)), 7.5*(10**(12)))
py.ylim(-4.5*(10**(12)), 8.5*(10**(12)))
#ax.add_artist(circle1)
ax.imshow(img,extent=[-22.5*(10**(12)), 22.2*(10**(12)), -10.75*(10**(12)), 10.5*(10**(12))])
py.rcParams["figure.figsize"] = (12.0, 11.0)
py.show()

# %%
import matplotlib.animation as animation
import matplotlib.colors as mcolors
img =  py.imread("black.jpg")
fig = py.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-6.5*(10**(12)), 6.5*(10**(12)))
ax.set_ylim(-4.5*(10**(12)), 8.5*(10**(12)))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xS[:i], yS[:i], color='crimson',linewidth = 0.0001)
    line1e, = ax.plot(xS[head_e], yS[head_e], color='aqua',marker='4',markersize = 20)
    line2, = ax.plot(xA[:i], yA[:i], color='white',linewidth = 0.0001)
    line2e, = ax.plot(xA[head_e], yA[head_e], color='orangered',marker='o',markersize = 8)
    line3, = ax.plot(xSBH[:i], ySBH[:i], color='white',linewidth = 0.0001)
    line3e, = ax.plot(xSBH[head_e], ySBH[head_e], color='black',marker='8',markersize = 8.5,markeredgewidth=0.5, markeredgecolor='white') 
    line4, = ax.plot(xBH[:i], yBH[:i], color='cadetblue')
    line4e, = ax.plot(xBH[head_e], yBH[head_e], color='black',marker='o',markersize = 10.9)
    lines.append([line1,line1e,line2,line2e,line3,line3e,line4,line4e])
#ax.add_artist(circle1)
ax.imshow(img,extent=[-22.5*(10**(12)), 22.2*(10**(12)), -10.75*(10**(12)), 10.5*(10**(12))])
py.legend([line1e, line2e, line3e, line4e], ['Ship','Death Star','Smaller Black Hole','Black Hole'],loc='lower right',prop={'size': 11})
ani = animation.ArtistAnimation(fig,lines,interval=0.006,blit=True)
ani.save('binary_death.gif')

# %%
with open('binary_death.gif','rb') as file:
    display(Image(file.read()))

# %% [markdown]
# # Binary Black Hole Escape

# %%
#Escape the Black Hole game  Aliens catch you
import numpy as np
import matplotlib.pyplot as py
from scipy.integrate import odeint


def deriv(s, t, G, mBH, mA, mS, mSBH):
    xS0 = s[0]
    vxS0 = s[1]
    yS0 = s[2]
    vyS0 = s[3]
    xBH0 = s[4]
    vxBH0 = s[5]
    yBH0 = s[6]
    vyBH0 = s[7]
    xA0 = s[8]
    vxA0 = s[9]
    yA0 = s[10]
    vyA0 = s[11]
    xSBH0 = s[12]
    vxSBH0 = s[13]
    ySBH0 = s[14]
    vySBH0 = s[15]

    f1 = vxS0
    f2 = ((G*mSBH*(xSBH0-xS0))/(((xSBH0-xS0)**2+(ySBH0-yS0)**2)**(1.5))) + ((G*mBH*(xBH0-xS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
    f3 = vyS0
    f4 = ((G*mSBH*(ySBH0-yS0))/(((xSBH0-xS0)**2+(ySBH0-yS0)**2)**(1.5))) + ((G*mBH*(yBH0-yS0))/(((xBH0-xS0)**2+(yBH0-yS0)**2)**(1.5)))
    f5 = 0.04*vxBH0
    f6 = ((G*mA*(xA0-xBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mSBH*(xSBH0-xBH0))/(((xSBH0-xBH0)**2+(ySBH0-yBH0)**2)**(1.5)))
    f7 = 0.04*vyBH0
    f8 = ((G*mA*(yA0-yBH0))/(((xA0-xBH0)**2+(yA0-yBH0)**2)**(1.5))) + ((G*mSBH*(ySBH0-yBH0))/(((xSBH0-xBH0)**2+(ySBH0-yBH0)**2)**(1.5)))
    f9 = vxA0
    f10 = ((G*mSBH*(xSBH0-xA0))/(((xSBH0-xA0)**2+(ySBH0-yA0)**2)**(1.5))) + ((G*mBH*(xBH0-xA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
    f11 = vyA0
    f12 = ((G*mSBH*(ySBH0-yA0))/(((xSBH0-xA0)**2+(ySBH0-yA0)**2)**(1.5))) + ((G*mBH*(yBH0-yA0))/(((xBH0-xA0)**2+(yBH0-yA0)**2)**(1.5)))
    f13 = vxSBH0
    f14 = 1.002*((G*mBH*(xBH0-xSBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(xA0-xSBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
    #f14 = 1.3008*((G*mBH*(xBH0-xSBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(xA0-xSBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
    f15 = vySBH0
    f16 = 1.0*((G*mBH*(yBH0-ySBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(yA0-ySBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
    #f16 = 1.2955*((G*mBH*(yBH0-ySBH0))/(((xBH0-xSBH0)**2+(yBH0-ySBH0)**2)**(1.5))) + ((G*mA*(yA0-ySBH0))/(((xA0-xSBH0)**2+(yA0-ySBH0)**2)**(1.5)))
  
  
  
  
    return [f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f16]

def diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params):
    t = np.linspace(tmin,tmax,nts)
    s = odeint(deriv, s_initial, t, params)
    
    return t,s
#Black hole binary system at the heart of a faraway galaxy, OJ 287
#https://www.scientificamerican.com/article/astronomers-measure-how-fast-a-supermassive-black-hole-is-spinning/#:~:text=OJ%20287%2C%20a%20binary%20supermassive,mere%20150%20million%20solar%20masses.

G = 6.67430*(10**(-11))
mBH = 3.6498*(10**40)#Massive black hole - 18.35 billion solar masses
mSBH = 2.9835e38 #Smaller black hole - 150 million solar masses
mA = 2.5*(10**18)#Mass of the Death Star
mS = 3.0*(10**6)#Mass of Saturn V


#Schwarzschild radius of Sagitarius A is 5.415e+10, 362AU

xS0 = -3.81127030e12
vxS0 = (0.95893*(3*(10**8))) #m/s #this works at .01c but we want a bigger curve so we changed it
yS0 = 6.0e12
vyS0 = (0.640789)*(3*(10**8)) #m/s - choose this to escape
#vyS0 = (0.640749)*(3*(10**8)) #m/s - choose this to escape
#vyS0 = (0.640719)*(3*(10**8)) #m/s - choose this to escape
#vyS0 = (0.640869)*(3*(10**8)) #m/s - choose this to escape
vyS0 = (0.285991)*(3*(10**8)) #m/s - choose this to escape
#vyS0 = -20000*np.sqrt(G*mA/np.abs(xS0-xA0))
#vyS0 = (0.991)*(3*(10**8)) #m/s up to this speed will never escape the black hole
#vyS0 = (0.988)*(3*(10**8)) #m/s minimum speed to escape, there is not speed possible above 1.0*c - for most calculating plot above, not this particlar small scale view
xBH0 = 0.0
vxBH0 = 0.0
yBH0 = 0.0
vyBH0 = 0.0
xA0 = -4.7*(10**(12))
vxA0 = (0.72)*(3*(10**8))
yA0 = 0.0
vyA0 =  0.7426*np.sqrt(G*mBH/np.abs(xA0))
#vyA0 =  0.97*np.sqrt(G*mBH/np.abs(xA0))
#vyA0 =  0.9*np.sqrt(G*mBH/np.abs(xA0))
xSBH0 = 1.813*(10**(12)) #10 lightweeks
vxSBH0 = -(1.2)*(3*(10**8))
ySBH0 = 0.1*(10**(10))
vySBH0 =  -(2.29*(3*(10**8)))

s_initial = [xS0, vxS0, yS0, vyS0,xBH0, vxBH0, yBH0, vyBH0, xA0, vxA0, yA0, vyA0, xSBH0, vxSBH0, ySBH0, vySBH0]
tmin = 0
#tmax = 265200
#tmax = 5000000
tmax = 2.7322e5 #12 years
tmax = 105560
nts = 850
params = (G, mBH, mA, mS, mSBH)

(t,s) = diffeq_solver_from_scipy(s_initial, tmin, tmax, nts, deriv, params)


xS = s[:,0]
vxS = s[:,1]
yS = s[:,2]
vyS = s[:,3]
xBH = s[:,4]
vxBH = s[:,5]
yBH = s[:,6]
vyBH = s[:,7]
xA = s[:,8]
vxA = s[:,9]
yA = s[:,10]
vyA = s[:,11]
xSBH = s[:,12]
vxSBH = s[:,13]
ySBH = s[:,14]
vySBH = s[:,15]

circle1 = py.Circle((0,0), 5.41*(10**(10)), color='k')
img = py.imread("black.jpg")


py.plot(xA, yA, 'm.', label='UFO')
py.plot(xSBH, ySBH,'b.',label='Smaller BH')
py.plot(xS, yS, 'r3',label='Ship Orbit')
py.plot(xBH, yBH,'ko',label='Massive BH', markersize = 5)
py.legend(loc='lower left')
fig = py.gcf()
ax = fig.gca()
py.title("Expedition Escape the Black Hole")
py.xlabel("X position (m)")
py.ylabel("Y position (m)")
py.xlim(-7.5*(10**(12)), 7.5*(10**(12)))
py.ylim(-4.5*(10**(12)), 8.5*(10**(12)))
#ax.add_artist(circle1)
ax.imshow(img,extent=[-22.5*(10**(12)), 22.2*(10**(12)), -10.75*(10**(12)), 10.5*(10**(12))])
py.rcParams["figure.figsize"] = (12.0, 10.0)
py.show()

# %%
import matplotlib.animation as animation
import matplotlib.colors as mcolors
img =  py.imread("black.jpg")
fig = py.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlim(-6.5*(10**(12)), 6.5*(10**(12)))
ax.set_ylim(-4.5*(10**(12)), 8.5*(10**(12)))
circle1 = py.Circle((0, 0), 7.86*(10**(9)), color='k') 
lines = []
for i in range(len(t)):
    head_e = i-1
    line1, = ax.plot(xS[:i], yS[:i], color='crimson',linewidth = 0.0001)
    line1e, = ax.plot(xS[head_e], yS[head_e], color='aqua',marker='4',markersize = 20)
    line2, = ax.plot(xA[:i], yA[:i], color='white',linewidth = 0.0001)
    line2e, = ax.plot(xA[head_e], yA[head_e], color='orangered',marker='o',markersize = 8)
    line3, = ax.plot(xSBH[:i], ySBH[:i], color='white',linewidth = 0.0001)
    line3e, = ax.plot(xSBH[head_e], ySBH[head_e], color='black',marker='8',markersize = 8.5,markeredgewidth=0.5, markeredgecolor='white') 
    line4, = ax.plot(xBH[:i], yBH[:i], color='cadetblue')
    line4e, = ax.plot(xBH[head_e], yBH[head_e], color='black',marker='o',markersize = 10.9)
    lines.append([line1,line1e,line2,line2e,line3,line3e,line4,line4e])
#ax.add_artist(circle1)
ax.imshow(img,extent=[-22.5*(10**(12)), 22.2*(10**(12)), -10.75*(10**(12)), 10.5*(10**(12))])
py.legend([line1e, line2e, line3e, line4e], ['Ship','Death Star','Smaller Black Hole','Black Hole'],loc='lower right',prop={'size': 11})
ani = animation.ArtistAnimation(fig,lines,interval=0.006,blit=True)
ani.save('binary_escape.gif')

# %%
with open('binary_escape.gif','rb') as file:
    display(Image(file.read()))
